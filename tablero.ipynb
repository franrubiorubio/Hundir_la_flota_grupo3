# %%
pip install numpy
# Out:
# ...
#   Using cached numpy-2.3.4-cp313-cp313-win_amd64.whl.metadata (60 kB)
# Using cached numpy-2.3.4-cp313-cp313-win_amd64.whl (12.8 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import random 
class Tablero :
    def __init__(self , id_jugador, filas=10, columnas=10 , agua="~"):
        self.filas = filas
        self.columnas = columnas
        self.id_jugador = id_jugador
        self.agua = agua

    def crear_tablero (self):
        self.tablero=np.full((self.filas, self.columnas), self.agua)
        self.tablero_mascara = self.tablero.copy()
        return self.tablero
    

    def coloca_barco(self, barco):
    # Nos devuelve el tablero si puede colocar el barco, si no devuelve False, y avise por pantalla
        tablero_temp = self.tablero.copy()  #hago una copia del tablero y trabajo con ella 
        num_max_filas = self.tablero.shape[0]
        num_max_columnas = self.tablero.shape[1]
        for pieza in barco:
            fila = pieza[0]
            columna = pieza[1]
            if fila < 0  or fila >= num_max_filas:
                print(f"No puedo poner la pieza {pieza} porque se sale del tablero")
                return False
            if columna < 0 or columna >= num_max_columnas:
                print(f"No puedo poner la pieza {pieza} porque se sale del tablero")
                return False
            if self.tablero[pieza] == "O" or self.tablero[pieza] == "X":
                print(f"No puedo poner la pieza {pieza} porque hay otro barco")
                return False
        
            tablero_temp[pieza] = "O"
        return tablero_temp



tablero_jugador = Tablero("jugador") 
tablero_jugador.crear_tablero()

tablero_maquina = Tablero("maquina")
tablero_maquina.crear_tablero()
# Out:
# array([['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~']], dtype='<U1')

# %%
tablero_jugador.coloca_barco([(0,1),(1,1)])
# Out:
# array([['~', 'O', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', 'O', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~']], dtype='<U1')

# %%
tablero_jugador.tablero
# Out:
# array([['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~']], dtype='<U1')

# %%
def crea_barco_aleatorio(self, tablero, eslora = 4, num_intentos = 100):
    num_max_filas = self.tablero.shape[0]
    num_max_columnas = self.tablero.shape[1]
    contador = 0
    while contador <= num_intentos:
        contador += 1
        barco = []
        pieza_inicio = (random.randint(0,num_max_filas-1), random.randint(0, num_max_columnas -1))
        print("Pieza original:", pieza_inicio)
        barco.append(pieza_inicio)
        orientacion = random.choice(["N","S","O","E"])
        print("Con orientacion", orientacion)
        fila = pieza_inicio[0]
        columna = pieza_inicio[1]
        for i in range(eslora - 1):
            if orientacion == "N":
                fila -= 1
            elif orientacion  == "S":
                fila += 1
            elif orientacion == "E":
                columna += 1
            elif orientacion == "O":
                columna -= 1
            pieza = (fila,columna)
            barco.append(pieza)
        
        tablero_temp = coloca_barco( barco)
        if type(tablero_temp) == np.ndarray:
            return tablero_temp

# %%
class Barco :
  
    def __init__ (self,nombre , eslora, id_jugador):
        self.nombre= nombre
        self.eslora= eslora 
        self.id_jugador = id_jugador
        self.tablero = Tablero(id_jugador)
        self.tablero.crear_tablero()

    def crea_barco_aleatorio(self, tablero, eslora = 4, num_intentos = 100):
       
       
        num_max_filas = self.tablero.tablero.shape[0]
        num_max_columnas = self.tablero.tablero.shape[1]
        contador = 0
       
        while contador <= num_intentos:
            contador += 1
            barco = []
            pieza_inicio = (random.randint(0,num_max_filas-1), random.randint(0, num_max_columnas -1))
            print("Pieza original:", pieza_inicio)
            barco.append(pieza_inicio)
            orientacion = random.choice(["N","S","O","E"])
            print("Con orientacion", orientacion)
            fila = pieza_inicio[0]
            columna = pieza_inicio[1]
            for i in range(eslora - 1):
                if orientacion == "N":
                    fila -= 1
                elif orientacion  == "S":
                    fila += 1
                elif orientacion == "E":
                    columna += 1
                elif orientacion == "O":
                    columna -= 1
                pieza = (fila,columna)
                barco.append(pieza)
        
            tablero_temp = self.tablero.coloca_barco( barco)
            if type(tablero_temp) == np.ndarray:
                return tablero_temp

# %%
barco_jugador = Barco(2,"barco1","jugador")
barco_maquina = Barco(1,"barco2", "maquina")



barco_jugador.crea_barco_aleatorio(tablero_jugador)
barco_maquina.crea_barco_aleatorio(tablero_maquina)
# Out:
# Pieza original: (9, 3)
# Con orientacion E
# Pieza original: (6, 9)
# Con orientacion N
# array([['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', 'O'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', 'O'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', 'O'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', 'O'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~'],
#        ['~', '~', '~', '~', '~', '~', '~', '~', '~', '~']], dtype='<U1')
